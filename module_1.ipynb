# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Accept input from user and store it in variable and print the value.
a = int(input("Enter number: "))
print (a)
# Out:
# Enter number: 5
# 5

# %%
# Use of print statements and use of (.format )for printing different data types
a=4
b=str(a)
print (type(b))
print (b)
# Out:
# <class 'str'>
# 4

# %%
#Take 2 numbers as user input and add, multiply, divide, subtract, remainder and print the output
a=int(input("Enter num1: "))
b=int(input("Enter num2: "))
sum = a + b
sub = a - b
mul = a * b
div = a / b
rem = a % b

print (sum)
print (sub)
print (mul)
print (div)
print (rem)
# Out:
# Enter num1: 10
# Enter num2: 5
# 15
# 5
# 50
# 2.0
# 0

# %%
#Conversion of one unit to another
hours = int(input("Enter hour: "))
minutes = 60 * hours
print (minutes)
# Out:
# Enter hour: 5
# 300

# %%
#calculator using switch
print ("Enter 1 for addition")
print ("Enter 2 for subtraction")
print ("Enter 3 for multiplication")
print ("Enter 4 for division")
op = int(input("Enter number corresponding to operation:"))
a=int(input("Enter num1: "))
b=int(input("Enter num2: "))
if op == 1:
  print(a + b)
elif op == 2:
  print(a - b)
elif op == 3:
  print(a - b)
elif op == 4:
  print(a - b)
else:
  print("Enter a valid input")
# Out:
# Enter 1 for addition
# Enter 2 for subtraction
# Enter 3 for multiplication
# Enter 4 for division
# Enter number corresponding to operation:2
# Enter num1: 15
# Enter num2: 5
# 10

# %%
sub1 = int(input("Enter marks in sub1: "))
sub2 = int(input("Enter marks in sub2: "))
sub3 = int(input("Enter marks in sub3: "))
sub4 = int(input("Enter marks in sub4: "))
sub5 = int(input("Enter marks in sub5: "))
#sub1
if sub1 >= 90:
  print("A in sub1")
elif (90 > sub1 >= 80):
  print("B in sub1")
elif (80 > sub1 >= 70):
  print("C in sub1")
elif (70 > sub1 >= 60):
  print("D in sub1")
elif (60 > sub1 >= 50):
  print("E in sub1")
else:
  print("f")
#sub2
if sub2 >= 90:
  print("A in sub2")
elif (90 > sub2 >= 80):
  print("B in sub2")
elif (80 > sub2 >= 70):
  print("C in sub2")
elif (70 > sub2 >= 60):
  print("D in sub2")
elif (60 > sub2 >= 50):
  print("E in sub2")
else:
  print("f")
#sub3
if sub3 >= 90:
  print("A in sub3")
elif (90 > sub3 >= 80):
  print("B in sub3")
elif (80 > sub3 >= 70):
  print("C in sub3")
elif (70 > sub3 >= 60):
  print("D in sub3")
elif (60 > sub3 >= 50):
  print("E in sub3")
else:
  print("f")
#sub4
if sub4 >= 90:
  print("A in sub4")
elif (90 > sub4 >= 80):
  print("B in sub4")
elif (80 > sub4 >= 70):
  print("C in sub4")
elif (70 > sub4 >= 60):
  print("D in sub4")
elif (60 > sub4 >= 50):
  print("E in sub4")
else:
  print("f")
#sub5
if sub5 >= 90:
  print("A in sub5")
elif (90 > sub5 >= 80):
  print("B in sub5")
elif (80 > sub5 >= 70):
  print("C in sub5")
elif (70 > sub5 >= 60):
  print("D in sub5")
elif (60 > sub5 >= 50):
  print("E in sub5")
else:
  print("f")
# Out:
# Enter marks in sub1: 75
# Enter marks in sub2: 90
# Enter marks in sub3: 16
# Enter marks in sub4: 85
# Enter marks in sub5: 60
# C in sub1
# A in sub2
# f
# B in sub4
# D in sub5

# %%
range = int(input("Enter range of numbers: "))
a = 0
while a < range:
  if a
