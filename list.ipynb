# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#append = adds at last pos
fruits = ['apple', 'banana', 'cherry']
fruits.append("orange")
print (fruits[3])

# %%
#insert
fruits = ['apple', 'banana', 'cherry','jack fruit']
print (fruits)
fruits.insert (2,"Mango")
print (fruits)

# %%
#remove
fruits = ['apple', 'banana', 'cherry','jack fruit']
print (fruits)
fruits.remove ("banana")
print (fruits)

# %%
#pop
fruits = ['apple','apple','banana', 'cherry','jack fruit']
print (fruits)
fruits.pop(1)
print (fruits)

# %%
#number descending sort
num = ["1","5","9","4","-2"]
print (num)
num.sort (reverse=True)
print (num)

# %%
#sort
alpha = ["a","e","c"]
print (alpha)
alpha.sort()
print (alpha)

# %%
#reverse
alpha = ["a","e","c"]
print (alpha)
alpha.reverse()
print (alpha)

# %%
#for loop
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)

# %%
#while loop
i = 1
while i < 6:
  print(i)
  i += 1
