# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/PYTHON_EXERCISE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Average of 3 numbers

# %%
a = 10
b = 15
c = 20

avg = (a+b+c)/3

print (avg)
# Out:
# 15.0

# %% [markdown]
# ### Multiplication of 3 numbers

# %%
a = 5
b = 4
c = 10

prod = a * b * c

print (prod)
# Out:
# 200

# %% [markdown]
# ###  Addition of 2 numbers (Dynamic)

# %%
a = int(input ("Enter the first number: "))
b = int(input ("Enter the second number: "))

c = a + b

print (c)
# Out:
# Enter the first number: 5
# Enter the second number: 10
# 15

# %% [markdown]
# ### Average of 3 numbers (Dynamic)

# %%
a = int(input ("Enter the first number: "))
b = int(input ("Enter the second number: "))
c = int(input ("Enter the third number: "))

avg = (a + b + c)/3

print (avg)
# Out:
# Enter the first number: 5
# Enter the second number: 10
# Enter the third number: 15
# 10.0

# %% [markdown]
# ## Type conversions
# ### Convert int to float

# %%
a = 10
b = float(a)
print (type(a))
print (type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### Convert float to int

# %%
a = 10.0
b = int (a)
print (type(a))
print (type(b))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ### Convert int to string

# %%
a = 10
b = str (a)
print (type (a))
print (type (b))
print (b)
# Out:
# <class 'int'>
# <class 'str'>
# 10

# %% [markdown]
# ### Convert string to int

# %%
a = "10"
b = int(a)
print (type (a))
print (type (b))
print (b)
# Out:
# <class 'str'>
# <class 'int'>
# 10

# %% [markdown]
# # Boolean to int

# %%
a = 10
b = a==1
c = int(b)
print(b)
print (type(b))
print(c)
print (type(c))
# Out:
# False
# <class 'bool'>
# 0
# <class 'int'>

# %% [markdown]
# ### Boolean to float

# %%
a = 10
b = a==1
c = float(b)
print(b)
print (type(b))
print(c)
print (type(c))
# Out:
# False
# <class 'bool'>
# 0.0
# <class 'float'>

# %% [markdown]
# ### Bool to str

# %%
a = 10
b = a==1
c = str(b)
print(b)
print (type(b))
print(c)
print (type(c))
# Out:
# False
# <class 'bool'>
# False
# <class 'str'>

# %% [markdown]
# ### Complex data type

# %%
a = 5 + 2j
print (type(a))
# Out:
# <class 'complex'>

# %%
a = 10 + 2j
c = str(a)
print(a)
print (type(a))
print(c)
print (type(c))
# Out:
# (10+2j)
# <class 'complex'>
# (10+2j)
# <class 'str'>

# %%
a = 10 + 2j
c = bool(a)
print(a)
print (type(a))
print(c)
print (type(c))
# Out:
# (10+2j)
# <class 'complex'>
# True
# <class 'bool'>
