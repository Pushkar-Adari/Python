# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Facts():
  print ("L")

Facts()
# Out:
# L

# %%
def f(a):
  print (a + "1")
f("a")
f("b")
# Out:
# a1
# b1

# %%
def f(a,b):
  print(a + " " + b)
f("a","b")
f("b","c")
# Out:
# a b
# b c

# %%
def f(*name):
  print(name[-1])

f("Amruth", "Prajwal", "Tej","Pushkar")
# Out:
# Pushkar

# %%
def Voting(age):
  print(age>=18)

Voting(9)
Voting(12)
Voting(34)
Voting(55)
Voting(69)
# Out:
# False
# False
# True
# True
# True
