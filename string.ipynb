# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "rrr movie has been released"
print (a.upper())
# Out:
# RRR MOVIE HAS BEEN RELEASED

# %%
#remove spaces
a = "        rrr movie has been released"
print (a.strip())
# Out:
# rrr movie has been released

# %%
a = "rrr movie has been released"
print (a.replace("rrr","Radhe Shyam"))
# Out:
# Radhe Shyam movie has been released

# %%
a = "rrr movie has been released"
print (a.split())
# Out:
# ['rrr', 'movie', 'has', 'been', 'released']

# %%
a = "rrr movie, has been released"
print (a.split(","))
# Out:
# ['rrr movie', ' has been released']

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
quantity = int(input("Enter quantity:"))
itemno = str(input("Enter item name:"))
price = int(input("Enter price:"))
total = quantity * price
myorder = "I bought {} packs of {} for {} rupees."
print(myorder.format(quantity, itemno, total))
# Out:
# Enter quantity:5
# Enter item name:chips
# Enter price:15
# I bought 5 packs of chips for 75 rupees.

# %%
sub1 = int(input("Enter marks:"))
sub2 = int(input("Enter marks:"))
sub3 = int(input("Enter marks:"))
sub4 = int(input("Enter marks:"))
marks = sub1 + sub2 + sub3 + sub4
result = "Got {} in sub1, {} in sub2, {} in sub3, {} in sub3 with a total of {}"
print(result.format(sub1, sub2, sub3,sub4,marks))
# Out:
# Enter marks:55
# Enter marks:99
# Enter marks:65
# Enter marks:12
# Got 55 in sub1, 99 in sub2, 65 in sub3, 12 in sub3 with a total of 231

# %%
txt = "We are the so-called \"Vikings\" from the north."
print (txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
txt = "rrr has been \breleased"
print (txt)
# Out:
# released

# %%
txt = "rrr has been \nreleased"
print (txt)
# Out:
# rrr has been
# released
