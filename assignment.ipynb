# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PRINT USING -1
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
print(Cars[-1])
# Out:
# Ferrari

# %%
#PRINT the entire list
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
print(Cars)
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
print(Cars[2:5])
# Out:
# ['Chrysler', 'Dodge', 'Ferrari']

# %%
#from beginning to forth
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
print(Cars[:4])
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge']

# %%
#from forth to end
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
print(Cars[4:])
# Out:
# ['Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
if "BMW" in Cars:
  print("Yes, 'BMW' is in the Cars list")
# Out:
# Yes, 'BMW' is in the Cars list

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars[1] = "Bugatti"
print(Cars)
# Out:
# ['Aston martin', 'Bugatti', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars[1:2] = ["Bugatti","Cadillac"]
print(Cars)
# Out:
# ['Aston martin', 'Bugatti', 'Cadillac', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars[1:2] = ["Bugatti"]
print(Cars)
# Out:
# ['Aston martin', 'Bugatti', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars.append("Merc")
print(Cars)
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge', 'Ferrari', 'Merc']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars.insert(1, "Pagani")
print(Cars)
# Out:
# ['Aston martin', 'Pagani', 'BMW', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Bikes = ["Ducati"]
Cars.extend(Bikes)
print(Cars)
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge', 'Ferrari', 'Ducati']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars.remove("BMW")
print(Cars)
# Out:
# ['Aston martin', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars.pop(1)
print(Cars)
# Out:
# ['Aston martin', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
del Cars[0]
print(Cars)
# Out:
# ['BMW', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
Cars.clear()
print(Cars)
# Out:
# []

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
for x in Cars:
  print (x)
# Out:
# Aston martin
# BMW
# Chrysler
# Dodge
# Ferrari

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
i = 0
while i < len(Cars):
  print(Cars[i])
  i = i + 1
# Out:
# Aston martin
# BMW
# Chrysler
# Dodge
# Ferrari

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]
[print(x) for x in Cars]
# Out:
# Aston martin
# BMW
# Chrysler
# Dodge
# Ferrari
# [None, None, None, None, None]

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]

newlist = [x for x in Cars if "e" in x]

print(newlist)
# Out:
# ['Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]

newlist = [x for x in Cars if x != "BMW"]
print (newlist)

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]

newlist = [x for x in Cars]
print (newlist)
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Chrysler","Dodge","Ferrari"]

newlist = [x.upper() for x in Cars]
print (newlist)
# Out:
# ['ASTON MARTIN', 'BMW', 'CHRYSLER', 'DODGE', 'FERRARI']

# %%
Cars = ["Aston martin","BMW","Dodge","Chrysler","Ferrari"]
Cars.sort()
print(Cars)
# Out:
# ['Aston martin', 'BMW', 'Chrysler', 'Dodge', 'Ferrari']

# %%
Cars = ["Aston martin","BMW","Dodge","Chrysler","Ferrari"]
cars = Cars.copy()
print (cars)
# Out:
# ['Aston martin', 'BMW', 'Dodge', 'Chrysler', 'Ferrari']
