# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar-Adari/Python/blob/main/Quiz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Square root of a number
number = int(input())
sqrt = number ** 0.5
print(sqrt)

# %%
#Swap 2 numbers
a = 2
b = 3

a = a + b
b = a - b
a = a - b

print ("Result =",a,b)

# %%
#Largest of 2 numbers
a = 2
b = 3
c = 5

if a>b and a>c:
    print (a)
elif b>a and b>c:
    print (b)
else:
    print (c)

# %%
#Insert into list
Rainbow = ['Red', 'Orange', 'Yellow', 'Green']

Rainbow.insert (3,"Black")

print(Rainbow)
